# %% [markdown]
# # Stellar Precession Tutorial
#
# This tutorial is about the precessing orbits of stars around a Black Hole. The Black Hole is assumed to be unaffected by stars (as it is more dense and more massive) and is stationary. The mass ratio of the Black Hole and the most massive star needs to be at least $10^3$ and the stars have very high velocity for the simulation to work accurately (regime where the assumptions hold).
#
# ## Import Necessary Libraries

# %%
from cosmicBallet.CelestialObjects import BlackHole, Stars
import cosmicBallet.utils.Constants as const
from cosmicBallet.MassiveObjectSimulator import SchwarzschildSimulator
# Out:
# QStandardPaths: wrong permissions on runtime directory /run/user/1000/, 0755 instead of 0700

# %%
mass = const.MS
radius = 6.96e8
speed = 0.1 * const.C
distance = 0.1 * const.AU

black_hole = BlackHole(name="Black Hole", mass=mass*1e6,
                       init_position=[0,0,0], init_velocity=[0,0,0])
star1 = Stars(name="A", mass=mass, temperature=3700, init_position=[distance,0,0],
              init_velocity=[0,2*speed,0], radius=radius)
star2 = Stars(name="B", mass=mass, temperature=5700, init_position=[-distance,0,0],
              init_velocity=[0,-2*speed,0], radius=radius)
star3 = Stars(name="C", mass=mass, temperature=7700, init_position=[0,distance,0],
              init_velocity=[-2*speed,0,0], radius=radius)
star4 = Stars(name="D", mass=mass, temperature=19700, init_position=[0,-distance,0],
              init_velocity=[2*speed,0,0], radius=radius)

# %% [markdown]
# ## Initialize and Simulate
#
# Initialize the simulation object and solve the problem. The problem is solved by default using the 4th Order Forest-Ruth Integration Scheme along with 1st PN Correction Term (to account for high speeds and high (but not extreme) gravitational field)

# %%
simulator = SchwarzschildSimulator(dense_body=black_hole, 
                                   stars=[star1, star2, star3, star4],
                                   time_step=1, simulation_time=1e3)
simulator.solve()

# %% [markdown]
# ## Visualize
#
# Similar to the N-Body Simulations, the visualization is integrated to the simulator class and can be called directly.
#
# ### Static Visual

# %%
simulator.visualize()

# %% [markdown]
# ### Matplotlib Animation

# %%
simulator.visualize(figure_name="Stellar_Precession_MPL", animate=True)
# Out:
# ffmpeg version 5.1.2 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 11.3.0 (conda-forge gcc 11.3.0-19)
#   configuration: --prefix=/home/sathya/miniconda3/envs/cosmicball --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1674566204550/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1674566204550/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1674566204550/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1674566204550/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libfontconfig --enable-libopenh264 --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-pthreads --enable-vaapi --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1674566204550/_build_env/bin/pkg-config
#   libavutil      57. 28.100 / 57. 28.100
#   libavcodec     59. 37.100 / 59. 37.100
#   libavformat    59. 27.100 / 59. 27.100
#   libavdevice    59.  7.100 / 59.  7.100
#   libavfilter     8. 44.100 /  8. 44.100
#   libswscale      6.  7.100 /  6.  7.100
#   libswresample   4.  7.100 /  4.  7.100
#   libpostproc    56.  6.100 / 56.  6.100
# Input #0, image2, from 'temp/data_%03d.png':
#   Duration: 00:00:04.00, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgba(pc), 1920x1440 [SAR 11811:11811 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# Output #0, mp4, to 'Stellar_Precession_MPL.mp4':
#   Metadata:
#     encoder         : Lavf59.27.100
#   Stream #0:0: Video: mpeg4 (mp4v / 0x7634706D), yuv420p(tv, progressive), 1920x1440 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 15 fps, 15360 tbn
#     Metadata:
#       encoder         : Lavc59.37.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  100 fps=0.0 q=2.0 Lsize=    3498kB time=00:00:06.60 bitrate=4341.7kbits/s speed=14.9x
# video:3497kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.038458%

# %% [markdown]
# ### 3D Animation
#
# For simulations where the objects are large enough and the distances short enough, a 3D animation can be used to visualize the orbits

# %%
simulator.visualize(visualization_type="animation", figure_name="Stellar_Precession_3D",
                    animate=True, save_figure=True)
# Out:
# [<cosmicBallet.CelestialObjects.BlackHole object at 0x7f2c00e3ff10>, <cosmicBallet.CelestialObjects.Stars object at 0x7f2c00757790>, <cosmicBallet.CelestialObjects.Stars object at 0x7f2c00752b10>, <cosmicBallet.CelestialObjects.Stars object at 0x7f2c00e00250>, <cosmicBallet.CelestialObjects.Stars object at 0x7f2c0076d1d0>]
# ffmpeg version 5.1.2 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 11.3.0 (conda-forge gcc 11.3.0-19)
#   configuration: --prefix=/home/sathya/miniconda3/envs/cosmicball --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1674566204550/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1674566204550/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1674566204550/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1674566204550/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libfontconfig --enable-libopenh264 --enable-gnutls --enable-libmp3lame --enable-libvpx --enable-pthreads --enable-vaapi --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1674566204550/_build_env/bin/pkg-config
#   libavutil      57. 28.100 / 57. 28.100
#   libavcodec     59. 37.100 / 59. 37.100
#   libavformat    59. 27.100 / 59. 27.100
#   libavdevice    59.  7.100 / 59.  7.100
#   libavfilter     8. 44.100 /  8. 44.100
#   libswscale      6.  7.100 /  6.  7.100
#   libswresample   4.  7.100 /  4.  7.100
#   libpostproc    56.  6.100 / 56.  6.100
# Input #0, image2, from 'temp/data_%03d.png':
#   Duration: 00:00:04.00, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 1280x670, 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# Output #0, mp4, to 'Stellar_Precession_3D.mp4':
#   Metadata:
#     encoder         : Lavf59.27.100
#   Stream #0:0: Video: mpeg4 (mp4v / 0x7634706D), yuv420p(tv, progressive), 1280x670, q=2-31, 200 kb/s, 15 fps, 15360 tbn
#     Metadata:
#       encoder         : Lavc59.37.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  100 fps=0.0 q=2.0 Lsize=     224kB time=00:00:06.60 bitrate= 278.2kbits/s speed=  38x
# video:223kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.575302%
